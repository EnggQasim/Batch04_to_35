# %% [markdown]
# # Marks Sheet Grading Example for AI, ML and DL

# %%
import numpy as np
import pandas as pd

# %%
df1 = pd.DataFrame(np.random.randint(20,32, size=(5000,5)),
                 columns=['s1','s2','s3','s4','s5'])
df2 = pd.DataFrame(np.random.randint(33,39, size=(5000,5)),
                 columns=['s1','s2','s3','s4','s5'])
df3 = pd.DataFrame(np.random.randint(40,49, size=(5000,5)),
                 columns=['s1','s2','s3','s4','s5'])
df4 = pd.DataFrame(np.random.randint(50,59, size=(5000,5)),
                 columns=['s1','s2','s3','s4','s5'])
df5 = pd.DataFrame(np.random.randint(60,69, size=(5000,5)),
                 columns=['s1','s2','s3','s4','s5'])
df6 = pd.DataFrame(np.random.randint(70,79, size=(5000,5)),
                 columns=['s1','s2','s3','s4','s5'])
df7 = pd.DataFrame(np.random.randint(80,100, size=(5000,5)),
                 columns=['s1','s2','s3','s4','s5'])

df = pd.concat([df1,df2,df3,df4,df5,df6,df7])

del df1,df2,df3,df4,df5,df6,df7

df.head()
# Out:
#    s1  s2  s3  s4  s5
# 0  21  27  29  23  21
# 1  29  27  31  24  25
# 2  20  21  20  31  30
# 3  27  26  25  26  20
# 4  20  28  21  27  27

# %%
df.shape
# Out:
# (35000, 5)

# %%
df['obtained'] = df.s1 + df.s2 + df.s3 + df.s4 + df.s5
df.head()
# Out:
#    s1  s2  s3  s4  s5  obtained
# 0  21  27  29  23  21       121
# 1  29  27  31  24  25       136
# 2  20  21  20  31  30       122
# 3  27  26  25  26  20       124
# 4  20  28  21  27  27       123

# %%
df['obtained'] = df.loc[:,'s1':'s5'].sum(axis=1)
df.head()
# Out:
#    s1  s2  s3  s4  s5  obtained
# 0  21  27  29  23  21       121
# 1  29  27  31  24  25       136
# 2  20  21  20  31  30       122
# 3  27  26  25  26  20       124
# 4  20  28  21  27  27       123

# %%
#                                total 
df['percentage'] = df.obtained / 500 * 100
df.head(7)
# Out:
#    s1  s2  s3  s4  s5  obtained  percentage
# 0  21  27  29  23  21       121        24.2
# 1  29  27  31  24  25       136        27.2
# 2  20  21  20  31  30       122        24.4
# 3  27  26  25  26  20       124        24.8
# 4  20  28  21  27  27       123        24.6
# 5  21  25  26  30  30       132        26.4
# 6  26  21  28  30  30       135        27.0

# %% [markdown]
# # apply Symbolic AI, Classicial programming, tranditional programming, Rules Based programmin
# - Rules always define by programmer

# %% [markdown]
# - Rules + Input = Output

# %%
def grade(x): # defined rules
    if x >= 80:
        return "A+"
    elif x >= 70:
        return "A"
    elif x >= 60:
        return "B"
    elif x >= 50:
        return "C"
    elif x >= 40:
        return "D"
    elif x >= 33:
        return "E"
    else:
        return "F"
    
    
df['Grade'] = df.percentage.apply(grade)
df.tail()
# Out:
#       s1  s2  s3  s4  s5  obtained  percentage Grade
# 4995  82  88  99  90  93       452        90.4    A+
# 4996  97  82  95  81  85       440        88.0    A+
# 4997  87  86  99  83  96       451        90.2    A+
# 4998  83  83  82  96  96       440        88.0    A+
# 4999  83  87  95  97  94       456        91.2    A+

# %%
df.percentage
# Out:
# 0       24.2
# 1       27.2
# 2       24.4
# 3       24.8
# 4       24.6
#         ...
# 4995    90.4
# 4996    88.0
# 4997    90.2
# 4998    88.0
# 4999    91.2
# Name: percentage, Length: 35000, dtype: float64

# %%
df.Grade.value_counts()
# Out:
# F     5000
# E     5000
# D     5000
# A+    5000
# A     5000
# C     5000
# B     5000
# Name: Grade, dtype: int64

# %%
df.corr().plot(kind='bar')

# %%
dic = {
    'F':7,
    "E":6,
    "D":5,
    "C":4,
    "B":3,
    "A":2,
    "A+":1
}
df['Grade1'] = df.Grade.map(dic)
df.head()
# Out:
#    s1  s2  s3  s4  s5  obtained  percentage Grade  Grade1
# 0  21  27  29  23  21       121        24.2     F       7
# 1  29  27  31  24  25       136        27.2     F       7
# 2  20  21  20  31  30       122        24.4     F       7
# 3  27  26  25  26  20       124        24.8     F       7
# 4  20  28  21  27  27       123        24.6     F       7

# %%
df.corr().plot(kind='bar')

# %% [markdown]
# # Find Grades(Rules) with Deep Learning
# - input + Output = Rules

# %%
df1 = df[['s1', 's2', 's3', 's4', 's5', 'Grade']]
df1.head(2)
df1 = df1.sample(frac=1)
df1.head(10)
# Out:
#       s1  s2  s3  s4  s5 Grade
# 4157  94  85  82  87  80    A+
# 4190  48  40  40  44  40     D
# 2307  82  81  94  99  89    A+
# 1731  63  62  66  68  63     B
# 2709  63  67  68  60  64     B
# 2783  74  70  71  78  78     A
# 4848  36  34  34  35  38     E
# 1158  77  77  72  76  78     A
# 1236  90  93  90  80  80    A+
# 4520  55  54  53  56  54     C

# %%
X = df1.loc[:, 's1':'s5']
X.head()
# Out:
#       s1  s2  s3  s4  s5
# 4157  94  85  82  87  80
# 4190  48  40  40  44  40
# 2307  82  81  94  99  89
# 1731  63  62  66  68  63
# 2709  63  67  68  60  64

# %%
Y = df1[['Grade']]
Y.head()
# Out:
#      Grade
# 4157    A+
# 4190     D
# 2307    A+
# 1731     B
# 2709     B

# %% [raw]
# # A     B     C      D
#  .30   .20   .35    .15   = 1
# #              OK

# %% [markdown]
# # Vectorization to Y
# - one-hot-encoding

# %% [raw]
#    A+ A B C D E F
# A+ 1  0 0 0 0 0 0
# A  0  1 0 0 0 0 0
# B  0  0 1 0 0 0 0
# C  0  0 0 1 0 0 0
# D  0  0 0 0 1 0 0
# E  0  0 0 0 0 1 0
# F  0  0 0 0 0 0 1
#
# D = 0000100
# B = 0100000

# %%
Y = df1['Grade']
Y = pd.get_dummies(Y)
Y.head()
# Out:
#       A  A+  B  C  D  E  F
# 4157  0   1  0  0  0  0  0
# 4190  0   0  0  0  1  0  0
# 2307  0   1  0  0  0  0  0
# 1731  0   0  1  0  0  0  0
# 2709  0   0  1  0  0  0  0

# %%
Y.drop_duplicates()
# Out:
#       A  A+  B  C  D  E  F
# 4157  0   1  0  0  0  0  0
# 4190  0   0  0  0  1  0  0
# 1731  0   0  1  0  0  0  0
# 2783  1   0  0  0  0  0  0
# 4848  0   0  0  0  0  1  0
# 4520  0   0  0  1  0  0  0
# 743   0   0  0  0  0  0  1

# %% [raw]
#    s1 s2 s3 s4 s5     A+   A  B  C   D   E   F
# [[98,56,79,90,50]] = [.3, .1,.20,.1, .1, .1, .1]

# %% [markdown]
# ##### import some fundamentals lib

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.optimizers import Adam, SGD

# %% [markdown]
# Create your model network structure
# - first-layer (input_shape = X.no_of_columns)
# - last-layers (output=Y.unique_labels(unique classes))
#     - activation = according to your problems (Table 4.1)
# - Dense(output, )

# %%
model = Sequential()
model.add(Dense(32, activation='relu', input_shape=(5,)))
model.add(Dense(16, activation='relu'))
model.add(Dense(7, activation='softmax'))

# %%
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_3 (Dense)              (None, 32)                192
# _________________________________________________________________
# dense_4 (Dense)              (None, 16)                528
# _________________________________________________________________
# dense_5 (Dense)              (None, 7)                 119
# =================================================================
# Total params: 839
# Trainable params: 839
# Non-trainable params: 0
# _________________________________________________________________

# %%
# select loss function based on your problems

model.compile(optimizer=SGD(lr=0.002),
             loss='categorical_crossentropy',
             metrics=['acc'])

# %%
model.fit(X, Y, epochs=100) # Training
# Out:
# Epoch 1/100
# 1094/1094 [==============================] - 3s 2ms/step - loss: 2.4903 - acc: 0.1560
# Epoch 2/100
# 1094/1094 [==============================] - 2s 2ms/step - loss: 1.7712 - acc: 0.2266
# Epoch 3/100
# 1094/1094 [==============================] - 2s 2ms/step - loss: 1.6846 - acc: 0.2871
# Epoch 4/100
# 1094/1094 [==============================] - 2s 2ms/step - loss: 1.5979 - acc: 0.3413
# Epoch 5/100
# 1094/1094 [==============================] - 2s 2ms/step - loss: 1.5090 - acc: 0.3869
# Epoch 6/100
# 1094/1094 [==============================] - 2s 2ms/step - loss: 1.4214 - acc: 0.4539
# Epoch 7/100
# 1094/1094 [==============================] - 2s 2ms/step - loss: 1.3455 - acc: 0.4926
# Epoch 8/100
# 1094/1094 [==============================] - 2s 2ms/step - loss: 1.2835 - acc: 0.5380
# Epoch 9/100
# 1094/1094 [==============================] - 2s 2ms/step - loss: 1.2096 - acc: 0.5818
# Epoch 10/100
# 1094/1094 [==============================] - 2s 2ms/step - loss: 1.1438 - acc: 0.6073
# Epoch 11/100
# 1094/1094 [==============================] - 2s 2ms/step - loss: 1.0960 - acc: 0.6220
# Epoch 12/100
# 1094/1094 [==============================] - 2s 2ms/step - loss: 1.0365 - acc: 0.6571
# Epoch 13/100
# 1094/1094 [==============================] - 2s 2ms/step - loss: 0.9979 - acc: 0.6729
# Epoch 14/100
# 1094/1094 [==============================] - 2s 2ms/step - loss: 0.9549 - acc: 0.6833
# Epoch 15/100
# 1094/1094 [==============================] - 2s 2ms/step - loss: 0.9222 - acc: 0.6985
# Epoch 16/100
# 1094/1094 [==============================] - 2s 2ms/step - loss: 0.8851 - acc: 0.7131
# Epoch 17/100
# 1094/1094 [==============================] - 2s 2ms/step - loss: 0.8529 - acc: 0.7219
# Epoch 18/100
# 1094/1094 [==============================] - 2s 2ms/step - loss: 0.8273 - acc: 0.7376
# Epoch 19/100
# 1094/1094 [==============================] - 2s 2ms/step - loss: 0.8010 - acc: 0.7606
# Epoch 20/100
# 1094/1094 [==============================] - 2s 2ms/step - loss: 0.7650 - acc: 0.7728
# Epoch 21/100
# 1094/1094 [==============================] - 2s 2ms/step - loss: 0.7524 - acc: 0.7625
# Epoch 22/100
# 1094/1094 [==============================] - 2s 2ms/step - loss: 0.7173 - acc: 0.7841
# Epoch 23/100
# 1094/1094 [==============================] - 2s 2ms/step - loss: 0.7083 - acc: 0.7765
# Epoch 24/100
# 1094/1094 [==============================] - 2s 2ms/step - loss: 0.6830 - acc: 0.7965
# Epoch 25/100
# 1094/1094 [==============================] - 2s 2ms/step - loss: 0.6665 - acc: 0.8008
# Epoch 26/100
# 1094/1094 [==============================] - 2s 2ms/step - loss: 0.6518 - acc: 0.8087
# Epoch 27/100
# 1094/1094 [==============================] - 2s 2ms/step - loss: 0.6417 - acc: 0.8106
# Epoch 28/100
# 1094/1094 [==============================] - 2s 2ms/step - loss: 0.6220 - acc: 0.8214
# Epoch 29/100
# 1094/1094 [==============================] - 2s 2ms/step - loss: 0.6279 - acc: 0.8037
# Epoch 30/100
# 1094/1094 [==============================] - 2s 2ms/step - loss: 0.5890 - acc: 0.8439
# Epoch 31/100
# 1094/1094 [==============================] - 2s 2ms/step - loss: 0.6097 - acc: 0.8158
# Epoch 32/100
# 1094/1094 [==============================] - 2s 2ms/step - loss: 0.6035 - acc: 0.8130
# Epoch 33/100
# 1094/1094 [==============================] - 2s 2ms/step - loss: 0.6636 - acc: 0.7584
# Epoch 34/100
# 1094/1094 [==============================] - 2s 2ms/step - loss: 0.5783 - acc: 0.8264
# Epoch 35/100
# 1094/1094 [==============================] - 2s 2ms/step - loss: 0.5935 - acc: 0.8058
# Epoch 36/100
# 1094/1094 [==============================] - 2s 2ms/step - loss: 0.5749 - acc: 0.8286
# Epoch 37/100
# 1094/1094 [==============================] - 2s 2ms/step - loss: 0.5834 - acc: 0.8269
# Epoch 38/100
# 1094/1094 [==============================] - 2s 2ms/step - loss: 0.6586 - acc: 0.7677
# Epoch 39/100
# 1094/1094 [==============================] - 2s 2ms/step - loss: 0.6322 - acc: 0.7695
# Epoch 40/100
# 1094/1094 [==============================] - 2s 2ms/step - loss: 0.6235 - acc: 0.7878
# Epoch 41/100
# 1094/1094 [==============================] - 2s 2ms/step - loss: 0.5868 - acc: 0.8046
# Epoch 42/100
# 1094/1094 [==============================] - 2s 2ms/step - loss: 0.6288 - acc: 0.7939
# Epoch 43/100
# 1094/1094 [==============================] - 2s 2ms/step - loss: 0.7040 - acc: 0.7499
# Epoch 44/100
# 1094/1094 [==============================] - 2s 2ms/step - loss: 0.6231 - acc: 0.7931
# Epoch 45/100
# 1094/1094 [==============================] - 2s 2ms/step - loss: 0.7369 - acc: 0.7150
# Epoch 46/100
# 1094/1094 [==============================] - 2s 2ms/step - loss: 0.6291 - acc: 0.7925
# Epoch 47/100
# 1094/1094 [==============================] - 2s 2ms/step - loss: 0.5708 - acc: 0.8104
# Epoch 48/100
# 1094/1094 [==============================] - 2s 2ms/step - loss: 0.5701 - acc: 0.8245
# Epoch 49/100
# 1094/1094 [==============================] - 2s 2ms/step - loss: 0.6404 - acc: 0.7658
# Epoch 50/100
# 1094/1094 [==============================] - 2s 2ms/step - loss: 0.6101 - acc: 0.7844
# Epoch 51/100
# 1094/1094 [==============================] - 2s 2ms/step - loss: 0.6325 - acc: 0.7867
# Epoch 52/100
# 1094/1094 [==============================] - 2s 2ms/step - loss: 0.6228 - acc: 0.7790
# Epoch 53/100
# 1094/1094 [==============================] - 2s 2ms/step - loss: 0.6181 - acc: 0.8181
# Epoch 54/100
# 1094/1094 [==============================] - 2s 2ms/step - loss: 0.5809 - acc: 0.8309
# Epoch 55/100
# 1094/1094 [==============================] - 2s 2ms/step - loss: 0.6648 - acc: 0.7700
# Epoch 56/100
# 1094/1094 [==============================] - 2s 2ms/step - loss: 0.6354 - acc: 0.7749
# Epoch 57/100
# 1094/1094 [==============================] - 2s 2ms/step - loss: 0.6165 - acc: 0.7947
# Epoch 58/100
# 1094/1094 [==============================] - 2s 2ms/step - loss: 0.5817 - acc: 0.8239
# Epoch 59/100
# 1094/1094 [==============================] - 2s 2ms/step - loss: 0.5759 - acc: 0.7842
# Epoch 60/100
# 1094/1094 [==============================] - 2s 2ms/step - loss: 0.6018 - acc: 0.8055
# Epoch 61/100
# 1094/1094 [==============================] - 2s 2ms/step - loss: 0.5949 - acc: 0.8209
# Epoch 62/100
# 1094/1094 [==============================] - 2s 2ms/step - loss: 0.5743 - acc: 0.8088
# Epoch 63/100
# 1094/1094 [==============================] - 2s 2ms/step - loss: 0.6022 - acc: 0.7931
# Epoch 64/100
# 1094/1094 [==============================] - 2s 2ms/step - loss: 0.6961 - acc: 0.7643
# Epoch 65/100
# 1094/1094 [==============================] - 2s 2ms/step - loss: 0.5309 - acc: 0.8387
# Epoch 66/100
# 1094/1094 [==============================] - 2s 2ms/step - loss: 0.5802 - acc: 0.8297
# Epoch 67/100
# 1094/1094 [==============================] - 2s 2ms/step - loss: 0.5535 - acc: 0.8174
# Epoch 68/100
# 1094/1094 [==============================] - 2s 2ms/step - loss: 0.7360 - acc: 0.7930
# Epoch 69/100
# 1094/1094 [==============================] - 2s 2ms/step - loss: 0.5520 - acc: 0.8603
# Epoch 70/100
# 1094/1094 [==============================] - 2s 1ms/step - loss: 0.6859 - acc: 0.8133
# Epoch 71/100
# 1094/1094 [==============================] - 2s 2ms/step - loss: 0.5506 - acc: 0.8269
# Epoch 72/100
# 1094/1094 [==============================] - 2s 2ms/step - loss: 0.4916 - acc: 0.8475
# Epoch 73/100
# 1094/1094 [==============================] - 2s 2ms/step - loss: 0.4954 - acc: 0.8370
# Epoch 74/100
# 1094/1094 [==============================] - 2s 2ms/step - loss: 0.5733 - acc: 0.8225
# Epoch 75/100
# 1094/1094 [==============================] - 2s 2ms/step - loss: 0.4639 - acc: 0.8633
# Epoch 76/100
# 1094/1094 [==============================] - 2s 2ms/step - loss: 0.5574 - acc: 0.8498
# Epoch 77/100
# 1094/1094 [==============================] - 2s 2ms/step - loss: 0.6705 - acc: 0.7954
# Epoch 78/100
# 1094/1094 [==============================] - 2s 2ms/step - loss: 0.5332 - acc: 0.8510
# Epoch 79/100
# 1094/1094 [==============================] - 2s 2ms/step - loss: 0.7190 - acc: 0.7857
# Epoch 80/100
# 1094/1094 [==============================] - 2s 2ms/step - loss: 0.5051 - acc: 0.8462
# Epoch 81/100
# 1094/1094 [==============================] - 2s 2ms/step - loss: 0.5325 - acc: 0.8369
# Epoch 82/100
# 1094/1094 [==============================] - 2s 2ms/step - loss: 0.5056 - acc: 0.8719
# Epoch 83/100
# 1094/1094 [==============================] - 2s 2ms/step - loss: 0.5462 - acc: 0.8396
# Epoch 84/100
# 1094/1094 [==============================] - 2s 1ms/step - loss: 0.5368 - acc: 0.8232
# Epoch 85/100
# 1094/1094 [==============================] - 2s 1ms/step - loss: 0.4965 - acc: 0.8884
# Epoch 86/100
# 1094/1094 [==============================] - 2s 2ms/step - loss: 0.4648 - acc: 0.8720
# Epoch 87/100
# 1094/1094 [==============================] - 2s 2ms/step - loss: 0.5585 - acc: 0.8080
# Epoch 88/100
# 1094/1094 [==============================] - 2s 2ms/step - loss: 0.5022 - acc: 0.8465
# Epoch 89/100
# 1094/1094 [==============================] - 2s 1ms/step - loss: 0.6187 - acc: 0.8455
# Epoch 90/100
# 1094/1094 [==============================] - 2s 2ms/step - loss: 0.4646 - acc: 0.8776
# Epoch 91/100
# 1094/1094 [==============================] - 2s 2ms/step - loss: 0.7260 - acc: 0.8252
# Epoch 92/100
# 1094/1094 [==============================] - 2s 2ms/step - loss: 0.5635 - acc: 0.8522
# Epoch 93/100
# 1094/1094 [==============================] - 2s 2ms/step - loss: 0.5976 - acc: 0.8475
# Epoch 94/100
# 1094/1094 [==============================] - 2s 2ms/step - loss: 0.4526 - acc: 0.8669
# Epoch 95/100
# 1094/1094 [==============================] - 2s 2ms/step - loss: 0.4985 - acc: 0.8660
# Epoch 96/100
# 1094/1094 [==============================] - 2s 2ms/step - loss: 0.5014 - acc: 0.8614
# Epoch 97/100
# 1094/1094 [==============================] - 2s 2ms/step - loss: 0.6193 - acc: 0.8210
# Epoch 98/100
# 1094/1094 [==============================] - 2s 2ms/step - loss: 0.4914 - acc: 0.8541
# Epoch 99/100
# 1094/1094 [==============================] - 2s 2ms/step - loss: 0.6424 - acc: 0.8250
# Epoch 100/100
# 1094/1094 [==============================] - 2s 2ms/step - loss: 0.4953 - acc: 0.8693

# %%
model.save('gradeModel.hd5')
# Out:
# INFO:tensorflow:Assets written to: gradeModel.hd5/assets

# %%
df1 = pd.DataFrame(np.random.randint(20,100, size=(20,5)),
                  columns = ['s1','s2','s3','s4','s5'])

df1.head()
# Out:
#    s1  s2  s3  s4  s5
# 0  71  53  81  76  30
# 1  30  80  39  55  92
# 2  89  93  69  78  93
# 3  40  65  50  99  24
# 4  33  79  60  46  37

# %%
np.argmax(model.predict([[90,98,95,97,95]]))
# Out:
# 1

# %%
Y.columns.take(np.argmax(model.predict([[90,98,95,97,95]]), axis=1))
# Out:
# Index(['A+'], dtype='object')

# %%
df1['predict']=Y.columns.take(np.argmax(model.predict(df1.loc[:,'s1':'s5']), axis=1))
df1.tail(20)
# Out:
#     s1  s2  s3  s4  s5 predict
# 0   71  53  81  76  30       F
# 1   30  80  39  55  92      A+
# 2   89  93  69  78  93      A+
# 3   40  65  50  99  24       F
# 4   33  79  60  46  37       F
# 5   25  28  26  21  98      A+
# 6   92  45  86  25  65       F
# 7   98  78  48  55  22       F
# 8   82  99  86  72  78      A+
# 9   56  32  43  50  87      A+
# 10  44  39  27  48  69      A+
# 11  20  24  73  91  25       F
# 12  69  66  80  47  20      A+
# 13  97  52  43  74  87      A+
# 14  65  27  88  48  75       F
# 15  21  27  24  78  93      A+
# 16  44  82  99  33  40      A+
# 17  22  46  50  93  89      A+
# 18  63  88  61  50  37       F
# 19  92  57  77  99  24       F

# %% [markdown]
# # Find Grades(Rules) With Machine Learning

# %%
# Load libraries
from sklearn.tree import DecisionTreeClassifier # Import Decision Tree Classifier
from sklearn.model_selection import train_test_split # Import train_test_split function
from sklearn import metrics #Import scikit-learn metrics module for accuracy calculation

# %%
#split dataset in features and target variable
feature_cols = ['percentage']
X = df[feature_cols] # Features
y = df.Grade # Target variable

# %%
X.head(1)
# Out:
#    percentage
# 0        24.2

# %%
y.head(1)
# Out:
# 0    F
# Name: Grade, dtype: object

# %%
train_test_split??

# %%
# Split dataset into training set and test set
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=1) # 70% training and 30% test

# %%
# Create Decision Tree classifer object
clf = DecisionTreeClassifier()

# %%
# Train Decision Tree Classifer
clf = clf.fit(X_train,y_train)

# %%
#Predict the response for test dataset
y_pred = clf.predict(X_test)

# %%
# Model Accuracy, how often is the classifier correct?
print("Accuracy:",metrics.accuracy_score(y_test, y_pred))
# Out:
# Accuracy: 1.0

# %%
from sklearn import tree
import matplotlib.pyplot as plt

# %%
plt.figure(figsize=(15,10))
tree.plot_tree(clf, filled=tree, class_names=True,
              fontsize=8)
# Out:
# [Text(651.0, 498.3, 'X[0] <= 79.3\ngini = 0.857\nsamples = 24500\nvalue = [3520, 3543, 3516, 3469, 3505, 3494, 3453]\nclass = y[1]'),
#  Text(558.0, 407.70000000000005, 'X[0] <= 68.8\ngini = 0.833\nsamples = 20957\nvalue = [3520, 0, 3516, 3469, 3505, 3494, 3453]\nclass = y[0]'),
#  Text(465.0, 317.1, 'X[0] <= 59.0\ngini = 0.8\nsamples = 17437\nvalue = [0, 0, 3516, 3469, 3505, 3494, 3453]\nclass = y[2]'),
#  Text(372.0, 226.5, 'X[0] <= 39.2\ngini = 0.75\nsamples = 13921\nvalue = [0, 0, 0, 3469, 3505, 3494, 3453]\nclass = y[4]'),
#  Text(186.0, 135.89999999999998, 'X[0] <= 31.8\ngini = 0.5\nsamples = 6947\nvalue = [0, 0, 0, 0, 0, 3494, 3453]\nclass = y[5]'),
#  Text(93.0, 45.299999999999955, 'gini = 0.0\nsamples = 3453\nvalue = [0, 0, 0, 0, 0, 0, 3453]\nclass = y[6]'),
#  Text(279.0, 45.299999999999955, 'gini = 0.0\nsamples = 3494\nvalue = [0, 0, 0, 0, 0, 3494, 0]\nclass = y[5]'),
#  Text(558.0, 135.89999999999998, 'X[0] <= 48.8\ngini = 0.5\nsamples = 6974\nvalue = [0, 0, 0, 3469, 3505, 0, 0]\nclass = y[4]'),
#  Text(465.0, 45.299999999999955, 'gini = 0.0\nsamples = 3505\nvalue = [0, 0, 0, 0, 3505, 0, 0]\nclass = y[4]'),
#  Text(651.0, 45.299999999999955, 'gini = 0.0\nsamples = 3469\nvalue = [0, 0, 0, 3469, 0, 0, 0]\nclass = y[3]'),
#  Text(558.0, 226.5, 'gini = 0.0\nsamples = 3516\nvalue = [0, 0, 3516, 0, 0, 0, 0]\nclass = y[2]'),
#  Text(651.0, 317.1, 'gini = 0.0\nsamples = 3520\nvalue = [3520, 0, 0, 0, 0, 0, 0]\nclass = y[0]'),
#  Text(744.0, 407.70000000000005, 'gini = 0.0\nsamples = 3543\nvalue = [0, 3543, 0, 0, 0, 0, 0]\nclass = y[1]')]
